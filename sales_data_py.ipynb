# %% [markdown]
# <a href="https://colab.research.google.com/github/danishmir123/data_sales.../blob/main/sales_data_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path="/content/sales_data.xlsx"
df=pd.read_excel(path)
df.head()
# Out:
#    Order ID        Date Customer   Product  Quantity  Price per Unit  \
# 0       101  2025-07-01    Alice    Laptop         1           70000
# 1       102  2025-07-02      Bob     Phone         2           30000
# 2       103  2025-07-03  Charlie    Tablet         1           25000
# 3       104  2025-07-04    David   Monitor         2           15000
# 4       105  2025-07-05      Eva  Keyboard         3            2000
#
#    Total Amount Payment Method
# 0         70000    Credit Card
# 1         60000            UPI
# 2         25000     Debit Card
# 3         30000           Cash
# 4          6000            UPI

# %%
grouped = df.groupby("Product")["Total Amount"].sum()
print(grouped)
# Out:
# Product
# Keyboard     6000
# Laptop      70000
# Monitor     30000
# Phone       60000
# Tablet      25000
# Name: Total Amount, dtype: int64

# %%
grouped.plot(kind='bar', title='Total Sales by Product', ylabel='Total Amount', xlabel='Product', color='skyblue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
